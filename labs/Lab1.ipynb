# %% [markdown]
# # Лабораторная работа №1
# ## Выполнила студентка группы БВТ2103 Пьянова Анна Олеговна

# %% [markdown]
# ### Оглавление
# 1. [Задание 1](#Задание-№1)
# 2. [Задание 2](#Задание-№2)
# 3. [Задание 3](#Задание-№3)
# 4. [Вывод](#Вывод)

# %% [markdown]
# ### Задание №1
# <i> Вызвать функцию print() и передать туда строку Hello, World! </i>

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Задание №2
# Написать генератор случайных матриц(многомерных), который принимает
# опциональные параметры <b>m</b>, <b>n</b>, <b>min_limit</b>, <b>max_limit</b>, где <b>m</b> и <b>n</b> указывают размер
# матрицы, а <b>min_lim</b> и <b>max_lim</b> - минимальное и максимальное значение для
# генерируемого числа.

# %%
import random

# %%
#метод для генерации матрицы
def generateArray(m=51, n=50, min_limit=54, max_limit=145):
    Matrix = [[random.randint(min_limit, max_limit) for j in range(n)] for i in range(m)]
    return Matrix

# %% [markdown]
# ### Задание №3
# Реализовать методы сортировки строк числовой матрицы в соответствии с
# заданием. Оценить время работы каждого алгоритма сортировки и сравнить его со
# временем стандартной функции сортировки. Испытания проводить на сгенерированных
# матрицах.

# %%
import random
import time
import copy
import matplotlib.pyplot as plt

# %%
#метод для сортировки выбором
def selectionSort(arr):
    a = arr.copy()
    for k in range(len(a)):
        for i in range(len(a[k]) - 1):
            m = i
            j = i + 1
            while j < len(a[k]):
                if a[k][j] < a[k][m]:
                    m = j
                j = j + 1
            a[k][i], a[k][m] = a[k][m], a[k][i]
    return a

arrayExample = generateArray()

start_time = time.time()
selectionSort(arrayExample)
print("Время работы сортировки выбором: " + "--- {0} ms ---".format(round((time.time() - start_time)*1000)))

arr = arrayExample.copy()
start_time = time.time()
arr.sort()
print("Время работы встроенной сортировки: " + "--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Время работы сортировки выбором: --- 14 ms ---
# Время работы встроенной сортировки: --- 1 ms ---

# %%
#метод для сортировки вставкой
def insertionSort(arr):
    a = arr.copy()
    for p in range(len(a)):
        for i in range(1, len(a[p])):
            k = a[p][i]
            j = i-1
            while j >= 0 and k < a[p][j]:
                a[p][j+1] = a[p][j]
                j -= 1
            a[p][j+1] = k
    return a

arrayExample = generateArray()

start_time = time.time()
insertionSort(arrayExample)
print("Время работы сортировки вставкой: " + "--- {0} ms ---".format(round((time.time() - start_time)*1000)))

arr = arrayExample.copy()
start_time = time.time()
arr.sort()
print("Время работы встроенной сортировки: " + "--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Время работы сортировки вставкой: --- 7 ms ---
# Время работы встроенной сортировки: --- 0 ms ---

# %%
#метод для сортировки обменом/пузырьком
def exchangeSort(arr):
    a = arr.copy()
    for p in range(len(a)):
        for i in range(len(a[p])):
            for j in range(len(a[p]) - i - 1):
                if a[p][j] > a[p][j + 1]:
                    a[p][j], a[p][j + 1] = a[p][j + 1], a[p][j]
    return a

arrayExample = generateArray()

start_time = time.time()
exchangeSort(arrayExample)
print("Время работы сортировки обменом/пузырьком: " + "--- {0} ms ---".format(round((time.time() - start_time)*1000)))

arr = arrayExample.copy()
start_time = time.time()
arr.sort()
print("Время работы встроенной сортировки: " + "--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Время работы сортировки обменом/пузырьком: --- 13 ms ---
# Время работы встроенной сортировки: --- 0 ms ---

# %%
#метод для сортировки Шелла
def shellsSort(arr):
    a = arr.copy()
    for p in range(len(a)):
        d = len(a) // 2
        while d:
            for i, el in enumerate(a[p]):
                while i >= d and a[p][i - d] > el:
                    a[p][i] = a[p][i - d]
                    i -= d
                a[p][i] = el
            d = 1 if d == 2 else int(d * 5.0 / 11)
    return a

arrayExample = generateArray()

start_time = time.time()
shellsSort(arrayExample)
print("Время работы сортировки Шелла: " + "--- {0} ms ---".format(round((time.time() - start_time)*1000)))

arr = arrayExample.copy()
start_time = time.time()
arr.sort()
print("Время работы встроенной сортировки: " + "--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Время работы сортировки Шелла: --- 8 ms ---
# Время работы встроенной сортировки: --- 0 ms ---

# %%
#метод для быстрой сортировки
def quickSort(arr):
    b = arr.copy()
    for i in range(len(b)):
        forQuickSort(0, len(b[i]) - 1, b, i)
    return b

#вспомогательный метод для быстрой сортировки
def forQuickSort(numFirst, numLast, array, line):
    first = int(numFirst)
    last = int(numLast)
    middle = int((first + last) / 2)

    while (first < last):

        while (array[line][first] < array[line][middle]):
            first += 1
        while (array[line][last] > array[line][middle]):
            last -= 1
        if (first <= last):
            array[line][first], array[line][last] = array[line][last], array[line][first]
            first += 1
            last -= 1

    if (numFirst < last):
        forQuickSort(numFirst, last, array, line)
    if (first < numLast):
        forQuickSort(first, numLast, array, line)

arrayExample = generateArray()

start_time = time.time()
quickSort(arrayExample)
print("Время работы быстрой сортировки: " + "--- {0} ms ---".format(round((time.time() - start_time)*1000)))

arr = arrayExample.copy()
start_time = time.time()
arr.sort()
print("Время работы встроенной сортировки: " + "--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Время работы быстрой сортировки: --- 5 ms ---
# Время работы встроенной сортировки: --- 1 ms ---

# %%
#метод для турнирной сортировки
def tournamentSort(arr):
    a = arr.copy()
    for i in range(len(a)):
        forTournamentSort(a[i])
    return a

#вспомогательный метод для турнирной сортировки
def forTournamentSort(arr):
    t = [None] * 2 * (len(arr) + len(arr) % 2)
    index = len(t) - len(arr) - len(arr) % 2

    for i, v in enumerate(arr):
        t[index + i] = (i, v)

    for j in range(len(arr)):
        n = len(arr)
        index = len(t) - len(arr) - len(arr) % 2
        while index > -1:
            n = (n + 1) // 2
            for i in range(n):
                i = max(index + i * 2, 1)
                if t[i] != None and t[i + 1] != None:
                    if t[i][1] < t[i + 1][1]:
                        t[i // 2] = t[i]
                    else:
                        t[i // 2] = t[i + 1]
                else:
                    t[i // 2] = t[i] if t[i] != None else t[i + 1]
            index -= n

        index, x = t[0]
        arr[j] = x
        t[len(t) - len(arr) - len(arr) % 2 + index] = None

arrayExample = generateArray()

start_time = time.time()
tournamentSort(arrayExample)
print("Время работы турнирной сортировки: " + "--- {0} ms ---".format(round((time.time() - start_time)*1000)))

arr = arrayExample.copy()
start_time = time.time()
arr.sort()
print("Время работы встроенной сортировки: " + "--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Время работы турнирной сортировки: --- 88 ms ---
# Время работы встроенной сортировки: --- 5 ms ---

# %%
#график для сортировки выбором
m = [51,62,65,73,76,82,89,92,95]
n = [51,62,65,73,76,82,89,92,95]
s = []
t = []
for i in range(9):
    s.append(m[i]*n[i])
    start_time = time.time()
    selectionSort(generateArray(m[i],n[i]))
    t.append((time.time() - start_time)*1000)
plt.ylabel("Time")
plt.xlabel("Matrix's size")
plt.plot(s, t, 'o-r', alpha=0.7, label="first", lw=5, mec='b', mew=2, ms=10)
plt.show()

# %%
#график для сортировки вставкой
m = [51,62,65,73,76,82,89,92,95]
n = [51,62,65,73,76,82,89,92,95]
s = []
t = []
for i in range(9):
    s.append(m[i]*n[i])
    start_time = time.time()
    insertionSort(generateArray(m[i],n[i]))
    t.append((time.time() - start_time)*1000)
plt.ylabel("Time")
plt.xlabel("Matrix's size")
plt.plot(s, t, 'o-r', alpha=0.7, label="first", lw=5, mec='b', mew=2, ms=10)
plt.show()

# %%
#график для сортировки пузырьком
m = [51,62,65,73,76,82,89,92,95]
n = [51,62,65,73,76,82,89,92,95]
s = []
t = []
for i in range(9):
    s.append(m[i]*n[i])
    start_time = time.time()
    exchangeSort(generateArray(m[i],n[i]))
    t.append((time.time() - start_time)*1000)
plt.ylabel("Time")
plt.xlabel("Matrix's size")
plt.plot(s, t, 'o-r', alpha=0.7, label="first", lw=5, mec='b', mew=2, ms=10)
plt.show()

# %%
#график для сортировки Шелла
m = [51,62,65,73,76,82,89,92,95]
n = [51,62,65,73,76,82,89,92,95]
s = []
t = []
for i in range(9):
    s.append(m[i]*n[i])
    start_time = time.time()
    shellsSort(generateArray(m[i],n[i]))
    t.append((time.time() - start_time)*1000)
plt.ylabel("Time")
plt.xlabel("Matrix's size")
plt.plot(s, t, 'o-r', alpha=0.7, label="first", lw=5, mec='b', mew=2, ms=10)
plt.show()

# %%
#график для быстрой сортировки
m = [51,62,65,73,76,82,89,92,95]
n = [51,62,65,73,76,82,89,92,95]
s = []
t = []
for i in range(9):
    s.append(m[i]*n[i])
    start_time = time.time()
    quickSort(generateArray(m[i],n[i]))
    t.append((time.time() - start_time)*1000)
plt.ylabel("Time")
plt.xlabel("Matrix's size")
plt.plot(s, t, 'o-r', alpha=0.7, label="first", lw=5, mec='b', mew=2, ms=10)
plt.show()

# %%
#график для турнирной сортировки 
m = [51,82,89,92,95]
n = [76,82,89,92,95]
s = []
t = []
for i in range(5):
    s.append(m[i]*n[i])
    start_time = time.time()
    tournamentSort(generateArray(m[i],n[i]))
    t.append((time.time() - start_time)*1000)
plt.ylabel("Time")
plt.xlabel("Matrix's size")
plt.plot(s, t, 'o-r', alpha=0.7, label="first", lw=5, mec='b', mew=2, ms=10)
plt.show()

# %% [markdown]
# ### Вывод

# %% [markdown]
# В ходе выполнения лабораторной работы мы написали генератор случайных многомерных матриц, а также реализовали методы сортировки строк числовой матрицы. Меньше всего потребовалось времени для реализации быстрой сортировки, больше всего - турнирной.
